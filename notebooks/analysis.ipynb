# %% [markdown]
# # Analysis
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import coffee data
coffee = pd.read_csv("../data/crop/coffee_output.csv")

# import weather data
weather = pd.read_csv("../data/weather/weater_output.csv")

# %%
# TODO: Merge these two dataframes together

coffee_weather = pd.merge(coffee, weather, left_on='year', right_on='year')

# %%
# TODO: View the first 5 rows of your data

coffee_weather.head()
# Out:
#   country   subdivision_x     type  60kgs_bag  year  nonbearing_trees  \
# 0  Brazil    Minas Gerais  Arabica       16.3  2006             581.0
# 1  Brazil  Espirito Santo  Arabica        2.2  2006             581.0
# 2  Brazil  Espirito Santo  Robusta        6.2  2006             581.0
# 3  Brazil       Sao Paulo  Arabica        3.3  2006             581.0
# 4  Brazil          Parana  Arabica        1.8  2006             581.0
#
#    bearing_trees  nonbear_hectares  bearing_hectares  \
# 0         5330.0             175.0            2298.0
# 1         5330.0             175.0            2298.0
# 2         5330.0             175.0            2298.0
# 3         5330.0             175.0            2298.0
# 4         5330.0             175.0            2298.0
#
#    bearing_trees_per_hectare  nonbearing_trees_per_hectare  rain_max  \
# 0                     2319.0                        3320.0  6.670968
# 1                     2319.0                        3320.0  6.670968
# ...

# %%
# TODO: Check for null values 

coffee_weather.isnull().sum()
# Out:
# country                         0
# subdivision_x                   0
# type                            0
# 60kgs_bag                       0
# year                            0
# nonbearing_trees                5
# bearing_trees                   5
# nonbear_hectares                5
# bearing_hectares                5
# bearing_trees_per_hectare       5
# nonbearing_trees_per_hectare    5
# rain_max                        0
# temp_avg                        0
# temp_max                        0
# temp_min                        0
# hum_max                         0
# hum_min                         0
# wind_max                        0
# wind_avg                        0
# subdivision_y                   0
# dtype: int64

# %%
# TODO: Drop rows that contain null values

coffee_weather_cleaned = coffee_weather.dropna()
coffee_weather_cleaned
# Out:
#    country   subdivision_x     type  60kgs_bag  year  nonbearing_trees  \
# 0   Brazil    Minas Gerais  Arabica       16.3  2006             581.0
# 1   Brazil  Espirito Santo  Arabica        2.2  2006             581.0
# 2   Brazil  Espirito Santo  Robusta        6.2  2006             581.0
# 3   Brazil       Sao Paulo  Arabica        3.3  2006             581.0
# 4   Brazil          Parana  Arabica        1.8  2006             581.0
# ..     ...             ...      ...        ...   ...               ...
# 89  Brazil    Minas Gerais  Arabica       28.5  2023            1510.0
# 90  Brazil  Espirito Santo  Arabica        4.4  2023            1510.0
# 91  Brazil  Espirito Santo  Robusta       16.6  2023            1510.0
# 92  Brazil       Sao Paulo  Arabica        5.1  2023            1510.0
# 93  Brazil          Parana  Arabica        0.8  2023            1510.0
#
#     bearing_trees  nonbear_hectares  bearing_hectares  \
# 0          5330.0             175.0            2298.0
# ...

# %%
# Select only rows in Minas Gerais
coffee_weather_cleaned = coffee_weather_cleaned[coffee_weather_cleaned['subdivision_x'] == 'Minas Gerais']
coffee_weather_cleaned
# Out:
#    country subdivision_x     type  60kgs_bag  year  nonbearing_trees  \
# 0   Brazil  Minas Gerais  Arabica      16.30  2006             581.0
# 5   Brazil  Minas Gerais  Arabica      23.70  2007             563.0
# 10  Brazil  Minas Gerais  Arabica      16.85  2008             679.0
# 15  Brazil  Minas Gerais  Arabica      25.55  2009             663.0
# 20  Brazil  Minas Gerais  Arabica      22.10  2010             873.0
# 25  Brazil  Minas Gerais  Arabica      28.50  2011             815.0
# 30  Brazil  Minas Gerais  Arabica      23.50  2012             835.0
# 35  Brazil  Minas Gerais  Arabica      28.50  2013            1000.0
# 40  Brazil  Minas Gerais  Arabica      29.40  2014            1055.0
# 49  Brazil  Minas Gerais  Arabica      26.00  2015            1185.0
# 54  Brazil  Minas Gerais  Arabica      25.30  2016            1125.0
# 59  Brazil  Minas Gerais  Arabica      32.50  2017            1300.0
# 69  Brazil  Minas Gerais  Arabica      34.20  2019            1150.0
# ...

# %%
# TODO: BEGIN YOUR EDA!

# Q1, calculate the Pearson's Correlation Coefficient between temp_avg and 60kgs_bag
sns.lmplot(
    data=coffee_weather_cleaned, x="temp_avg", y="60kgs_bag", scatter_kws={"s": 50, "alpha": 1}
)
coffee_weather_cleaned[["temp_avg", "60kgs_bag"]].corr()
# Out:
#            temp_avg  60kgs_bag
# temp_avg   1.000000  -0.124772
# 60kgs_bag -0.124772   1.000000

# %%
# Q2, calculate the Pearson's Correlation Coefficient between hum_min and 60kgs_bag
sns.lmplot(
    data=coffee_weather_cleaned, x="hum_min", y="60kgs_bag", scatter_kws={"s": 50, "alpha": 1}
)
coffee_weather_cleaned[["hum_min", "60kgs_bag"]].corr()
# Out:
#             hum_min  60kgs_bag
# hum_min    1.000000  -0.540171
# 60kgs_bag -0.540171   1.000000

# %%
# Q3, calculate the Pearson's Correlation Coefficient between rain_max and 60kgs_bag
sns.lmplot(
    data=coffee_weather_cleaned, x="rain_max", y="60kgs_bag", scatter_kws={"s": 50, "alpha": 1}
)
coffee_weather_cleaned[["rain_max", "60kgs_bag"]].corr()
# Out:
#            rain_max  60kgs_bag
# rain_max   1.000000  -0.395811
# 60kgs_bag -0.395811   1.000000

# %%
# Q4, calculate the Pearson's Correlation Coefficient between wind_avg and 60kgs_bag
sns.lmplot(
    data=coffee_weather_cleaned, x="wind_avg", y="60kgs_bag", scatter_kws={"s": 50, "alpha": 1}
)
coffee_weather_cleaned[["wind_avg", "60kgs_bag"]].corr()
# Out:
#            wind_avg  60kgs_bag
# wind_avg   1.000000  -0.707327
# 60kgs_bag -0.707327   1.000000

# %%
# Q5, calculate Pearson's Correlation Coefficient between weather columns (temp_avg, hum_min, rain_max, and wind_avg) and a coffee-related column, bearing_trees
coffee_weather_cleaned[["temp_avg", "bearing_trees"]].corr()
# Out:
#                temp_avg  bearing_trees
# temp_avg       1.000000      -0.426886
# bearing_trees -0.426886       1.000000

# %%
coffee_weather_cleaned[["hum_min", "bearing_trees"]].corr()
# Out:
#                 hum_min  bearing_trees
# hum_min        1.000000      -0.593017
# bearing_trees -0.593017       1.000000

# %%
coffee_weather_cleaned[["rain_max", "bearing_trees"]].corr()
# Out:
#                rain_max  bearing_trees
# rain_max       1.000000      -0.332832
# bearing_trees -0.332832       1.000000

# %%
coffee_weather_cleaned[["wind_avg", "bearing_trees"]].corr()
# Out:
#                wind_avg  bearing_trees
# wind_avg       1.000000      -0.598742
# bearing_trees -0.598742       1.000000

# %%
coffee_weather_cleaned[["temp_avg", "nonbearing_trees"]].corr()
# Out:
#                   temp_avg  nonbearing_trees
# temp_avg           1.00000          -0.37299
# nonbearing_trees  -0.37299           1.00000

# %%
coffee_weather_cleaned[["hum_min", "nonbearing_trees"]].corr()
# Out:
#                    hum_min  nonbearing_trees
# hum_min           1.000000         -0.310333
# nonbearing_trees -0.310333          1.000000

# %%
coffee_weather_cleaned[["rain_max", "nonbearing_trees"]].corr()
# Out:
#                   rain_max  nonbearing_trees
# rain_max          1.000000         -0.036131
# nonbearing_trees -0.036131          1.000000

# %%
coffee_weather_cleaned[["wind_avg", "nonbearing_trees"]].corr()
# Out:
#                   wind_avg  nonbearing_trees
# wind_avg          1.000000         -0.903117
# nonbearing_trees -0.903117          1.000000

# %%
coffee_weather_cleaned[["temp_avg", "bearing_trees_per_hectare"]].corr()
# Out:
#                            temp_avg  bearing_trees_per_hectare
# temp_avg                   1.000000                  -0.432076
# bearing_trees_per_hectare -0.432076                   1.000000

# %%
coffee_weather_cleaned[["hum_min", "bearing_trees_per_hectare"]].corr()
# Out:
#                             hum_min  bearing_trees_per_hectare
# hum_min                    1.000000                  -0.551204
# bearing_trees_per_hectare -0.551204                   1.000000

# %%
coffee_weather_cleaned[["rain_max", "bearing_trees_per_hectare"]].corr()
# Out:
#                            rain_max  bearing_trees_per_hectare
# rain_max                   1.000000                  -0.253524
# bearing_trees_per_hectare -0.253524                   1.000000

# %%
coffee_weather_cleaned[["wind_avg", "bearing_trees_per_hectare"]].corr()
# Out:
#                            wind_avg  bearing_trees_per_hectare
# wind_avg                   1.000000                  -0.893987
# bearing_trees_per_hectare -0.893987                   1.000000

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %% [markdown]
# What is the relationship between temp_avg and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# - The pearson's correlation coefficient temp_avg and 60kgs_bag is -0.124772, which indicates a very weak negative correlation.

# %% [markdown]
# What is the relationship between minimum humidity and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# - The pearson's correlation coefficient hum_min and 60kgs_bag is -0.540171, which indicates a slightly strong negative correlation.

# %% [markdown]
# What is the relationship between rain_max and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# - The pearson's correlation coefficient rain_max and 60kgs_bag is -0.395811, which indicates a weak negative correlation.

# %% [markdown]
# What is the relationship between average wind speed and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# - The pearson's correlation coefficient wind_avg and 60kgs_bag is -0.707327, which indicates a weak negative correlation. In the scatter plot, we can also see that data points are centered around a regression line.

# %% [markdown]
# Perform the same bivariate analysis between the mentioned weather columns (temp_avg, hum_min, rain_max, and wind_avg) and a coffee-related column of your choice (bearing_trees, nonbearing_trees, bearing_trees_per_hectare, etc). Which directions do these relationships follow? What are the strengths of these relationships?
#
# - When performing the weather columns with a coffee-related column, all of them shows negative correlations as shown by the negative Pearson's correlation coefficient between these variables.

# %% [markdown]
# Which weather factor seems to influence coffee production the most?
#
# - The wind_avg column shows the most negative Pearson's correlation coefficients for all coffee types (bearing_trees, nonbearing_trees, bearing_trees_per_hectare). Therefore, average wind speed seems to affect coffee production the most.

# %% [markdown]
# Which data would you collect to continue exploring the impacts of weather and economic forces on coffee production?
#
# - To explore the impacts of weather and economic forces on coffee production more, I would want to collect the data each month or quarter instead of a whole year because the weather can be affected by the season it's in. To understand economic factors, I would want to collect data on the net worth of all the local coffee farms each each month, quarter, or year and how the money was spent.

# %% [markdown]
# If you were preparing a report to provide coffee farmers, which weather condititions would you state are the most favorable for coffee growing (assuming any exist)?
#
# - Since the negative Pearson's correlation coefficients between the wind_avg column and all coffee types all show strong negative correlation, it means that lower wind speed is more likely to lead to more coffee growth.
