# %% [markdown]
# # Explore Cofffee
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import data
coffee = pd.read_csv("../data/crop/coffee_output.csv")

# %%
# TODO: view first 5 rows of your data
coffee.head()
# Out:
#   country     subdivision     type  60kgs_bag  year  nonbearing_trees  \
# 0  Brazil    Minas Gerais  Arabica       16.2  2002            1500.0
# 1  Brazil  Espirito Santo  Arabica        2.2  2002            1500.0
# 2  Brazil  Espirito Santo  Robusta        7.5  2002            1500.0
# 3  Brazil       Sao Paulo  Arabica        3.2  2002            1500.0
# 4  Brazil          Parana  Arabica        0.5  2002            1500.0
#
#    bearing_trees  nonbear_hectares  bearing_hectares  \
# 0         4465.0             495.0            2120.0
# 1         4465.0             495.0            2120.0
# 2         4465.0             495.0            2120.0
# 3         4465.0             495.0            2120.0
# 4         4465.0             495.0            2120.0
#
#    bearing_trees_per_hectare  nonbearing_trees_per_hectare
# 0                     2106.0                        3030.0
# 1                     2106.0                        3030.0
# ...

# %%
# TODO: describe your numeric columns
coffee.describe()
# Out:
#         60kgs_bag         year  nonbearing_trees  bearing_trees  \
# count  114.000000   114.000000        109.000000     109.000000
# mean     8.812281  2012.552632        994.495413    5646.926606
# std      9.051550     6.265642        310.338484     372.684151
# min      0.500000  2002.000000        466.000000    4465.000000
# 25%      2.600000  2007.000000        679.000000    5640.000000
# 50%      4.750000  2013.000000       1050.000000    5735.000000
# 75%     12.175000  2018.000000       1185.000000    5810.000000
# max     34.800000  2023.000000       1510.000000    6200.000000
#
#        nonbear_hectares  bearing_hectares  bearing_trees_per_hectare  \
# count        109.000000        109.000000                 109.000000
# mean         298.055046       2146.513761                2639.027523
# std           97.572559         96.699000                 245.497999
# min          148.000000       2010.000000                2106.000000
# ...

# %%
# TODO: display the null values in your dataframe
coffee[coffee.isnull().any(axis=1)]
# Out:
#    country     subdivision     type  60kgs_bag  year  nonbearing_trees  \
# 84  Brazil    Minas Gerais  Arabica       28.3  2018               NaN
# 85  Brazil  Espirito Santo  Arabica        3.3  2018               NaN
# 86  Brazil  Espirito Santo  Robusta        7.3  2018               NaN
# 87  Brazil       Sao Paulo  Arabica        4.3  2018               NaN
# 88  Brazil          Parana  Arabica        1.3  2018               NaN
#
#     bearing_trees  nonbear_hectares  bearing_hectares  \
# 84            NaN               NaN               NaN
# 85            NaN               NaN               NaN
# 86            NaN               NaN               NaN
# 87            NaN               NaN               NaN
# 88            NaN               NaN               NaN
#
#     bearing_trees_per_hectare  nonbearing_trees_per_hectare
# 84                        NaN                           NaN
# 85                        NaN                           NaN
# ...

# %%
# TODO: drop your null values
coffee_cleaned = coffee.dropna()
coffee_cleaned[coffee_cleaned.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [country, subdivision, type, 60kgs_bag, year, nonbearing_trees, bearing_trees, nonbear_hectares, bearing_hectares, bearing_trees_per_hectare, nonbearing_trees_per_hectare]
# Index: []

# %%
# TODO: Select only Minas Gerais
coffee_cleaned = coffee_cleaned[coffee_cleaned['subdivision']=='Minas Gerais']
coffee_cleaned
# Out:
#     country   subdivision     type  60kgs_bag  year  nonbearing_trees  \
# 0    Brazil  Minas Gerais  Arabica      16.20  2002            1500.0
# 5    Brazil  Minas Gerais  Arabica      26.70  2003            1125.0
# 10   Brazil  Minas Gerais  Arabica      14.40  2004             631.0
# 15   Brazil  Minas Gerais  Arabica      21.40  2005             466.0
# 20   Brazil  Minas Gerais  Arabica      16.30  2006             581.0
# 25   Brazil  Minas Gerais  Arabica      23.70  2007             563.0
# 30   Brazil  Minas Gerais  Arabica      16.85  2008             679.0
# 35   Brazil  Minas Gerais  Arabica      25.55  2009             663.0
# 40   Brazil  Minas Gerais  Arabica      22.10  2010             873.0
# 45   Brazil  Minas Gerais  Arabica      28.50  2011             815.0
# 50   Brazil  Minas Gerais  Arabica      23.50  2012             835.0
# 55   Brazil  Minas Gerais  Arabica      28.50  2013            1000.0
# ...

# %%
# TODO: BEGIN YOUR EDA!

# plot graph for Q1
plt.plot("year", "bearing_trees", data=coffee_cleaned)

# %%
# Histogram of the bearing_trees count
sns.histplot(data=coffee_cleaned, x="bearing_trees", bins=5)
coffee_cleaned["bearing_trees"].describe()
# Out:
# count      21.000000
# mean     5640.714286
# std       385.876553
# min      4465.000000
# 25%      5640.000000
# 50%      5735.000000
# 75%      5810.000000
# max      6200.000000
# Name: bearing_trees, dtype: float64

# %%
# number of samples in the cleaned data
coffee_cleaned.count()
# Out:
# country                         21
# subdivision                     21
# type                            21
# 60kgs_bag                       21
# year                            21
# nonbearing_trees                21
# bearing_trees                   21
# nonbear_hectares                21
# bearing_hectares                21
# bearing_trees_per_hectare       21
# nonbearing_trees_per_hectare    21
# dtype: int64

# %%
#  plot graph for Q2
plt.plot("year", "bearing_hectares", data=coffee_cleaned)

# %%
# Histogram of the bearing_hectares count
sns.histplot(data=coffee_cleaned, x="bearing_hectares", bins=5)
coffee_cleaned["bearing_hectares"].describe()
# Out:
# count      21.000000
# mean     2146.952381
# std       100.465156
# min      2010.000000
# 25%      2070.000000
# 50%      2135.000000
# 75%      2223.000000
# max      2360.000000
# Name: bearing_hectares, dtype: float64

# %%
# plot graph for Q3
plt.plot("year", "60kgs_bag", data=coffee_cleaned)

# %%
# Histogram of the bearing_hectares count
sns.histplot(data=coffee_cleaned, x="60kgs_bag", bins=10)
coffee_cleaned["60kgs_bag"].describe()
# Out:
# count    21.000000
# mean     25.142857
# std       5.792998
# min      14.400000
# 25%      22.100000
# 50%      25.550000
# 75%      28.500000
# max      34.800000
# Name: 60kgs_bag, dtype: float64

# %%
# Q4, calculate the Pearson's Correlation Coefficient between bearing_trees and 60kgs_bag
sns.scatterplot(data=coffee_cleaned, x="bearing_trees", y="60kgs_bag")
coffee_cleaned[["bearing_trees", "60kgs_bag"]].corr()
# Out:
#                bearing_trees  60kgs_bag
# bearing_trees       1.000000   0.655343
# 60kgs_bag           0.655343   1.000000

# %%
# Q5, calculate the Pearson's Correlation Coefficient between bearing_trees and 60kgs_bag
sns.scatterplot(data=coffee_cleaned, x="bearing_hectares", y="60kgs_bag")
coffee_cleaned[["bearing_hectares", "60kgs_bag"]].corr()
# Out:
#                   bearing_hectares  60kgs_bag
# bearing_hectares           1.00000   -0.48092
# 60kgs_bag                 -0.48092    1.00000

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %% [markdown]
# How is bearing trees changing across the years for Minas Gerais? Is this increasing or decreasing? What is the distribution of this variable? Is it normal?
# - The number of bearing trees has generally increased over the years. When plotting a histogram with 5 bins, it appears we can get a bell curve with most years having between 5250 to 6000 bearing trees. However, because there are only 21 samples in the cleaned dataset, based on the Central Limit Theorem which requires 30 samples in the dataset, we cannot conclude that this is a normal distribution.

# %% [markdown]
# How is bearing hectares changing across the years for Minas Gerais? Is this increasing or decreasing? What is the distribution of this variable? Is it normal?
#
# - Based on the line plot, the number of bearing hectares has generally decreased over the years. The histogram for the counts of the numbers does not appear to have a normal distribution. Like in the previous answer, we cannot conclude this is a normal distribution because we do not have enough samples.

# %% [markdown]
# How is the count of million 60kgs bags of coffee changing across the years for Minas Gerais? Is this increasing or decreasing? What is the distribution of this variable? Is it normal?
#
# - The count of million 60kgs bags is generally increasing over the years. When plotting a histogram, there seems to be a normal distribution centered at 27.5, but the median and mean are around 25. However, we cannot conclude this is a normal distribution as we do not have enough sample size.

# %% [markdown]
# What is the relationship between bearing_trees and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# - There's a slightly strong correlation between bearing_trees and 60kgs_bag because the Pearson's correlation coefficient for these two variables is 0.655343, which is between 0.5 - 1 (signaling a strong positive correlation) but closer to the 0.5 side.

# %% [markdown]
# What is the relationship between bearing_hectares and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# - There's a slightly weak correlation between bearing_hectares and 60kgs_bag because the Pearson's correlation coefficient for these two variables is -0.48092, which is between -0.5 - 0 (signaling a weak negative correlation) but it's closer to the 0.5 side.
